# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewRucker/Fantasy-Football-Betting-Projects/blob/main/Drafters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from IPython.core.pylabtools import figsize
from matplotlib import pyplot as plt
sns.set_context(font_scale=2)

# to bypass warnings in various dataframe assignments
pd.options.mode.chained_assignment = None

# %%
#Read in CSV to dataframe
url = 'https://raw.githubusercontent.com/AndrewRucker/Fantasy-Football-Betting-Projects/main/draftersTourney.csv'

df = pd.read_csv(url, index_col='User')

df
# Out:
#                           Pts           Player  ... Team.11 POS.11
# User                                            ...
# plustin (9)            340.26       Josh Allen  ...      KC     TE
# Loman147 (13)          325.16  Jimmy Garoppolo  ...      KC     TE
# Eaglezzz (53)          320.56       Josh Allen  ...      KC     TE
# aandt (6)              318.26       Josh Allen  ...      KC     TE
# plustin (39)           317.48  Patrick Mahomes  ...     ARI     TE
# ...                       ...              ...  ...     ...    ...
# redeemedwarriors (64)   59.90    Aaron Rodgers  ...      GB     TE
# coachp10 (2)            59.38     Kyler Murray  ...     BAL     TE
# getoffmyface (4)        55.18     Carson Wentz  ...     BAL     TE
# jimmoney                51.70     Carson Wentz  ...      GB     TE
# fasman247 (15)          51.56     Dak Prescott  ...     BAL     TE
#
# [3000 rows x 37 columns]

# %%
alive_teams = pd.Series(["KC", 'CIN', 'SF', 'LAR'])

# %%
df['1'] = df['Team'].isin(alive_teams)
df['2'] = df['Team.1'].isin(alive_teams)
df['3'] = df['Team.2'].isin(alive_teams)
df['4'] = df['Team.3'].isin(alive_teams)
df['5'] = df['Team.4'].isin(alive_teams)
df['6'] = df['Team.5'].isin(alive_teams)
df['7'] = df['Team.6'].isin(alive_teams)
df['8'] = df['Team.7'].isin(alive_teams)
df['9'] = df['Team.8'].isin(alive_teams)
df['10'] = df['Team.9'].isin(alive_teams)
df['11'] = df['Team.10'].isin(alive_teams)
df['12'] = df['Team.11'].isin(alive_teams)


df['Alive_count'] = 0


#df[df.Team == 'CIN'].shape[0]
df['Alive_count'] = np.where(df['1'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['2'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['3'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['4'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['5'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['6'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['7'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['8'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['9'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['10'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['11'], df['Alive_count'] + 1, df['Alive_count'])
df['Alive_count'] = np.where(df['12'], df['Alive_count'] + 1, df['Alive_count'])


df['Alive_count'].value_counts()



    
#df.sort_values(by='Alive_count', ascending=False)
# Out:
# 4     498
# 3     496
# 5     456
# 2     407
# 6     294
# 1     256
# 7     206
# 0     192
# 8     104
# 9      60
# 10     17
# 11      9
# 12      5
# Name: Alive_count, dtype: int64

# %%
#Read in CSV to dataframe
url1 = 'https://raw.githubusercontent.com/AndrewRucker/Fantasy-Football-Betting-Projects/main/draftersSecondChance.csv?_sm_au_=iVVwFfDJQQR1vJDFL321jK0f1JH33'

df1 = pd.read_csv(url1, index_col='User')

df1
# Out:
#                    Points           Player TEAM  ...         Player.9 TEAM.9 POS.9
# User                                             ...
# comebackzinc (16)  183.96       Josh Allen  BUF  ...     Tyler Higbee    LAR    TE
# Brownie2211        179.62  Patrick Mahomes   KC  ...     Travis Kelce     KC    TE
# Brewercory5 (9)    173.36       Josh Allen  BUF  ...   Rob Gronkowski     TB    TE
# Brewercory5 (23)   173.16       Josh Allen  BUF  ...   Rob Gronkowski     TB    TE
# VEGASDFS (13)      172.36       Josh Allen  BUF  ...   Rob Gronkowski     TB    TE
# ...                   ...              ...  ...  ...              ...    ...   ...
# Yaks23              49.20    Aaron Rodgers   GB  ...      Dawson Knox    BUF    TE
# trickyducky113      47.30  Jimmy Garoppolo   SF  ...   Josiah Deguara     GB    TE
# jasonbinette        47.20    Aaron Rodgers   GB  ...    George Kittle     SF    TE
# sparker             44.80    Aaron Rodgers   GB  ...   Marcedes Lewis     GB    TE
# ...

# %%
df1.columns
# Out:
# Index(['Points', 'Player', 'TEAM', 'POS', 'Player.1', 'TEAM.1', 'POS.1',
#        'Player.2', 'TEAM.2', 'POS.2', 'Player.3', 'TEAM.3', 'POS.3',
#        'Player.4', 'TEAM.4', 'POS.4', 'Player.5', 'TEAM.5', 'POS.5',
#        'Player.6', 'TEAM.6', 'POS.6', 'Player.7', 'TEAM.7', 'POS.7',
#        'Player.8', 'TEAM.8', 'POS.8', 'Player.9', 'TEAM.9', 'POS.9'],
#       dtype='object')

# %%
df1['1'] = df1['TEAM'].isin(alive_teams)
df1['2'] = df1['TEAM.1'].isin(alive_teams)
df1['3'] = df1['TEAM.2'].isin(alive_teams)
df1['4'] = df1['TEAM.3'].isin(alive_teams)
df1['5'] = df1['TEAM.4'].isin(alive_teams)
df1['6'] = df1['TEAM.5'].isin(alive_teams)
df1['7'] = df1['TEAM.6'].isin(alive_teams)
df1['8'] = df1['TEAM.7'].isin(alive_teams)
df1['9'] = df1['TEAM.8'].isin(alive_teams)
df1['10'] = df1['TEAM.9'].isin(alive_teams)


df1['Alive_count'] = 0


#df1[df1.TEAM == 'CIN'].shape[0]
df1['Alive_count'] = np.where(df1['1'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['2'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['3'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['4'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['5'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['6'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['7'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['8'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['9'], df1['Alive_count'] + 1, df1['Alive_count'])
df1['Alive_count'] = np.where(df1['10'], df1['Alive_count'] + 1, df1['Alive_count'])


df1['Alive_count'].value_counts()

    
#df1.sort_values(by='Alive_count', ascending=False)
# Out:
# 5     186
# 4     141
# 6     135
# 3     127
# 2      97
# 7      96
# 8      63
# 1      53
# 9      37
# 0      31
# 10     12
# Name: Alive_count, dtype: int64
